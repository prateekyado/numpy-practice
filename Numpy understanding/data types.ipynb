# %%
#Why Data Types Matter in NumPy
#The choice of data type affects:

#    Memory Usage: Smaller data types use less memory.
#    Performance: Operations on smaller data types are faster due to less data being processed.
#    Precision: Choosing the appropriate data type ensures that you don't lose precision 
#        (e.g., using float32 instead of float64 if you don't need that extra precision).

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype('float64')
# Out:
# array([1., 2., 3., 4.])

# %%
arr2 = np.array([23,45,33,25],dtype = 'float32')

# %%
arr2
# Out:
# array([23., 45., 33., 25.], dtype=float32)
